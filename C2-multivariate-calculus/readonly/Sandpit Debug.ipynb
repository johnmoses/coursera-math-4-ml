# %%
# Click into this cell and press [Shift-Enter] to start.
# %run "readonly/sandpit-exercises.ipynb"
sp = sandpit_random_test()

def next_step(f, J, H) :
    gamma = 0.5
    return -gamma * J

sp.next_step = next_step
sp.game_mode=2
sp.draw()
sp.showContours()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File /var/folders/7y/51xm0jxx13d_3br4x4tjk9ww0000gp/T/ipykernel_8634/3844735782.py:11
#       9 import matplotlib.lines as mlines
#      10 from matplotlib.legend_handler import HandlerLine2D
# ---> 11 from scipy.misc import imread
#      12 import matplotlib.cm as cm
#      13 from matplotlib.colors import LinearSegmentedColormap
#
# ImportError: cannot import name 'imread' from 'scipy.misc' (/Users/johnmoses/miniforge3/envs/mle/lib/python3.8/site-packages/scipy/misc/__init__.py)
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File /var/folders/7y/51xm0jxx13d_3br4x4tjk9ww0000gp/T/ipykernel_8634/2704842728.py:1
# ----> 1 get_ipython().run_line_magic('run', '"readonly/sandpitmodule.ipynb"')
#       3 def sandpit_intro():
#       4     sp = Sandpit(
#       5         lambda x,y: -((x-4.1)**2 + (y-0.9)**2) - 30*np.exp(-((x-1.5)**2 + (y-3.7)**2)/(2*1.4)),
#       6     )
#
# File ~/miniforge3/envs/mle/lib/python3.8/site-packages/IPython/core/interactiveshell.py:2364, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2362     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2363 with self.builtin_trap:
# -> 2364     result = fn(*args, **kwargs)
#    2365 return result
#
# File ~/miniforge3/envs/mle/lib/python3.8/site-packages/IPython/core/magics/execution.py:717, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     715     with preserve_keys(self.shell.user_ns, '__file__'):
#     716         self.shell.user_ns['__file__'] = filename
# --> 717         self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#     718     return
#     720 # Control the response to exit() calls made by the script being run
#
# File ~/miniforge3/envs/mle/lib/python3.8/site-packages/IPython/core/interactiveshell.py:2870, in InteractiveShell.safe_execfile_ipy(self, fname, shell_futures, raise_exceptions)
#    2868 result = self.run_cell(cell, silent=True, shell_futures=shell_futures)
#    2869 if raise_exceptions:
# -> 2870     result.raise_error()
#    2871 elif not result.success:
#    2872     break
#
# File ~/miniforge3/envs/mle/lib/python3.8/site-packages/IPython/core/interactiveshell.py:266, in ExecutionResult.raise_error(self)
#     264     raise self.error_before_exec
#     265 if self.error_in_exec is not None:
# --> 266     raise self.error_in_exec
#
#     [... skipping hidden 1 frame]
#
# File /var/folders/7y/51xm0jxx13d_3br4x4tjk9ww0000gp/T/ipykernel_8634/3844735782.py:11
#       9 import matplotlib.lines as mlines
#      10 from matplotlib.legend_handler import HandlerLine2D
# ---> 11 from scipy.misc import imread
#      12 import matplotlib.cm as cm
#      13 from matplotlib.colors import LinearSegmentedColormap
#
# ImportError: cannot import name 'imread' from 'scipy.misc' (/Users/johnmoses/miniforge3/envs/mle/lib/python3.8/site-packages/scipy/misc/__init__.py)
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Click into this cell and press [Shift-Enter] to start.
# ----> 2 get_ipython().run_line_magic('run', '"readonly/sandpit-exercises.ipynb"')
#       3 sp = sandpit_random_test()
#       5 def next_step(f, J, H) :
#
# File ~/miniforge3/envs/mle/lib/python3.8/site-packages/IPython/core/interactiveshell.py:2364, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2362     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2363 with self.builtin_trap:
# -> 2364     result = fn(*args, **kwargs)
#    2365 return result
#
# File ~/miniforge3/envs/mle/lib/python3.8/site-packages/IPython/core/magics/execution.py:717, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     715     with preserve_keys(self.shell.user_ns, '__file__'):
#     716         self.shell.user_ns['__file__'] = filename
# --> 717         self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#     718     return
#     720 # Control the response to exit() calls made by the script being run
#
# File ~/miniforge3/envs/mle/lib/python3.8/site-packages/IPython/core/interactiveshell.py:2870, in InteractiveShell.safe_execfile_ipy(self, fname, shell_futures, raise_exceptions)
#    2868 result = self.run_cell(cell, silent=True, shell_futures=shell_futures)
#    2869 if raise_exceptions:
# -> 2870     result.raise_error()
#    2871 elif not result.success:
#    2872     break
#
# File ~/miniforge3/envs/mle/lib/python3.8/site-packages/IPython/core/interactiveshell.py:266, in ExecutionResult.raise_error(self)
#     264     raise self.error_before_exec
#     265 if self.error_in_exec is not None:
# --> 266     raise self.error_in_exec
#
#     [... skipping hidden 1 frame]
#
# File /var/folders/7y/51xm0jxx13d_3br4x4tjk9ww0000gp/T/ipykernel_8634/2704842728.py:1
# ----> 1 get_ipython().run_line_magic('run', '"readonly/sandpitmodule.ipynb"')
#       3 def sandpit_intro():
#       4     sp = Sandpit(
#       5         lambda x,y: -((x-4.1)**2 + (y-0.9)**2) - 30*np.exp(-((x-1.5)**2 + (y-3.7)**2)/(2*1.4)),
#       6     )
#
# File ~/miniforge3/envs/mle/lib/python3.8/site-packages/IPython/core/interactiveshell.py:2364, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2362     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2363 with self.builtin_trap:
# -> 2364     result = fn(*args, **kwargs)
#    2365 return result
#
# File ~/miniforge3/envs/mle/lib/python3.8/site-packages/IPython/core/magics/execution.py:717, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     715     with preserve_keys(self.shell.user_ns, '__file__'):
#     716         self.shell.user_ns['__file__'] = filename
# --> 717         self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#     718     return
#     720 # Control the response to exit() calls made by the script being run
#
# File ~/miniforge3/envs/mle/lib/python3.8/site-packages/IPython/core/interactiveshell.py:2870, in InteractiveShell.safe_execfile_ipy(self, fname, shell_futures, raise_exceptions)
#    2868 result = self.run_cell(cell, silent=True, shell_futures=shell_futures)
#    2869 if raise_exceptions:
# -> 2870     result.raise_error()
#    2871 elif not result.success:
#    2872     break
#
# File ~/miniforge3/envs/mle/lib/python3.8/site-packages/IPython/core/interactiveshell.py:266, in ExecutionResult.raise_error(self)
#     264     raise self.error_before_exec
#     265 if self.error_in_exec is not None:
# --> 266     raise self.error_in_exec
#
#     [... skipping hidden 1 frame]
#
# File /var/folders/7y/51xm0jxx13d_3br4x4tjk9ww0000gp/T/ipykernel_8634/3844735782.py:11
#       9 import matplotlib.lines as mlines
#      10 from matplotlib.legend_handler import HandlerLine2D
# ---> 11 from scipy.misc import imread
#      12 import matplotlib.cm as cm
#      13 from matplotlib.colors import LinearSegmentedColormap
#
# ImportError: cannot import name 'imread' from 'scipy.misc' (/Users/johnmoses/miniforge3/envs/mle/lib/python3.8/site-packages/scipy/misc/__init__.py)

# %%
sp.revealed = False
sp.draw()
sp.nGuess = 0
sp.showContours()
# Out:
# <img src="data:image/png;base64,..." width="900">
